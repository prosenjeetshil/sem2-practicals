# %%
import numpy as np

def perception_

ult >= 0:
        return 1
    else:
        return 0

print(perception_or(0,0))
print(perception_or(0,1))
print(perception_or(1,0))
print(perception_or(1,1))
# Out:
# 0
# 1
# 1
# 1
