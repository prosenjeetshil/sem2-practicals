# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score


train = pd.read_csv('C:/Users/Lab2_30/Downloads/titanic.csv')
print(train.shape)
# Out:
# (891, 12)

# %%
NAs = pd.concat([train.isnull().sum()], axis=1, keys=["Train"])
NAs[NAs.sum(axis=1) > 0]
# Out:
#           Train
# Age         177
# Cabin       687
# Embarked      2

# %%
train.pop("Cabin")
train.pop("Name")
train.pop("Ticket")
# Out:
# 0             A/5 21171
# 1              PC 17599
# 2      STON/O2. 3101282
# 3                113803
# 4                373450
#              ...
# 886              211536
# 887              112053
# 888          W./C. 6607
# 889              111369
# 890              370376
# Name: Ticket, Length: 891, dtype: object

# %%
train.shape
# Out:
# (891, 9)

# %%
train["Age"] = train["Age"].fillna(train["Age"].mean())

# %%
train["Embarked"] = train["Embarked"].fillna(train["Embarked"].mode()[0])

# %%
train["Pclass"] = train["Pclass"].apply(str)

# %%
for col in train.dtypes[train.dtypes=="object"].index:
    for_dummy=train.pop(col)
    train=pd.concat([train, pd.get_dummies(for_dummy, prefix=col)], axis=1)
train.head()
# Out:
#    PassengerId  Survived   Age  SibSp  Parch     Fare  Pclass_1  Pclass_2  \
# 0            1         0  22.0      1      0   7.2500     False     False
# 1            2         1  38.0      1      0  71.2833      True     False
# 2            3         1  26.0      0      0   7.9250     False     False
# 3            4         1  35.0      1      0  53.1000      True     False
# 4            5         0  35.0      0      0   8.0500     False     False
#
#    Pclass_3  Sex_female  Sex_male  Embarked_C  Embarked_Q  Embarked_S
# 0      True       False      True       False       False        True
# 1     False        True     False        True       False       False
# 2      True        True     False       False       False        True
# 3     False        True     False       False       False        True
# 4      True       False      True       False       False        True

# %%
labels = train.pop("Survived")

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(train, labels, test_size = 0.25)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
df_model=DecisionTreeClassifier(max_depth=14)

# %%
df_model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=14)

# %%
train_y_hat=df_model.predict(x_train)
test_y_hat=df_model.predict(x_test)

# %%
y_pred=df_model.predict(x_test)

# %%
accuracy=accuracy_score(y_test,y_pred)

# %%
accuracy
# Out:
# 0.7802690582959642

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier

# %% [raw]
# boosting_model = AdaBoostClassifier(estimator=DecisionTreeClassifier(), n_estimators=50, random_state=42)

# %%
boosting_model.fit(x_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 boosting_model.fit(x_train, y_train)
#
# NameError: name 'boosting_model' is not defined

# %%
boosting_predictions = boosting_model.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 boosting_predictions = boosting_model.predict(x_test)
#
# NameError: name 'boosting_model' is not defined

# %%
boosting_accuracy = accuracy_score(y_test, boosting_predictions)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 boosting_accuracy = accuracy_score(y_test, boosting_predictions)
#
# NameError: name 'boosting_predictions' is not defined

# %%
print("Boosting Accuracy : ",boosting_accuracy)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 print("Boosting Accuracy : ",boosting_accuracy)
#
# NameError: name 'boosting_accuracy' is not defined

# %%
# gradient boosting

# %%
from sklearn.metrics import classification_report

print("\n Classification Report: \n",classification_report(y_test, y_pred))
# Out:
#  Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.85      0.80      0.83       146
#            1       0.66      0.74      0.70        77
#
#     accuracy                           0.78       223
#    macro avg       0.76      0.77      0.76       223
# weighted avg       0.79      0.78      0.78       223
